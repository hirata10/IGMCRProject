# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
from astropy.io import fits
import scipy.sparse
import scipy.linalg
import time

from astropy.io import fits # [added to write outputs. C.M.H.]

r0 = 2.818e-13 # classical electron radius in cm
m_e = 9.10938e-28 # electron mass in gram
c = 2.998e10 # speed of light in cm/s
h = 6.6261e-27 # planck constant in cm^2 g s-1
eV_to_erg = 1.6022e-12
parsec_to_cm = 3.085677581e18 # cm per parsec

kB = 1.3808e-16 # boltzmann constant in cm^2 g s^-2 K^-1
T_CMB = 2.725 # CMB temperature today in K

H_0 = 2.184e-18 # current hubble constant in s^-1
H_r = 3.24076e-18 # 100 km/s/Mpc to 1/s
h_0 = H_0 / H_r
omega_b_0 = 0.0224 / h_0 / h_0  # current baryon abundance
m_p = 1.67262193269e-24 # proton mass in g
G = 6.6743e-8 # gravitational constant in cm^3 g^-1 s^-2
f_He = 0.079 # helium mass fraction
f_H = 0.76 # hydrogen fraction
Y_He = 0.24

E_e = m_e * c * c
rho_crit = 3 * H_0 * H_0 / 8 / np.pi / G
e = 2.718281828459 # base of natural log

z = 2
z2 = (1 + z) / 3
T_CMB *= 1+z # scale to CMB temperature at that redshift <-- C.M.H.

# %%
with open('rate_z2_10Mpc_new.pkl', 'rb') as f:
    rata_arr_new = pkl.load(f)
print(np.array(rata_arr_new))
# Out:
# [4.56193675e-40 4.56193675e-40 4.56193675e-40 ...            nan
#             nan            nan]

# %%
with open('rate_z2_10Mpc_new.pkl', 'rb') as f:
    rata_arr = pkl.load(f)
    
rate_arr = np.array(rata_arr)
rate_arr = rate_arr.reshape(400,400) # [i][j]: gamma[i] theta[j], rate_arr[-1] = nan
rate_trans = np.transpose(rate_arr) # [i][j]: theta[i] gamma[j], rate_trans[i][-1] = nan
rate_trans[:,-1]=0. # remove nan <-- C.M.H.
fits.PrimaryHDU(rate_trans).writeto('rate_trans.fits', overwrite=True)

gamma_e_arr = np.logspace(8, 14, 400) * eV_to_erg / m_e / c**2 # lab-frame Lorentz factor of the electron produced
theta_e_arr = np.logspace(-8,0, 400)

# %% [markdown]
# ### generate theta_rms
# takes about 20 mins, can read next block directly

# %%
def compton_f(x):
    if x > 1e-2:
        return ((-24 - 144*x - 290*x**2 - 194*x**3 + 20*x**4 + 28*x**5) / 3 / x**2 / (1+2*x)**3 + (4+4*x-x**2) / x**3 * np.log(1+2*x))
    return 8/5*x**2 - 32/5*x**3 + 2248/105*x**4 - 1376/21*x**5 + 11840/63*x**6

def compton_FF(x):
    n = 1024
    y = np.linspace(x / (2 * n), x - x / (2 * n), n)
    result = 0.
    for i in range(n): result += compton_f(y[i]) * y[i]
    result *= x / n
    return result

# %%
jtable = np.loadtxt('EBL_KS18_Q18_z_ 2.0.txt')
nstep = np.shape(jtable)[0] - 1
jtable[:,0] = 2.99792458e18 / jtable[:,0] # convert to Hz
nu = (jtable[:-1,0] + jtable[1:,0]) / 2
dnu = (jtable[:-1,0] - jtable[1:,0])
JnuEBL = (jtable[:-1,1] + jtable[1:,1]) / 2

xx = h*nu/kB/T_CMB
Bnu = 2 * h * nu**3 / c**2 / np.expm1(xx)
Jnu = JnuEBL + Bnu
# Out:
# /var/folders/k2/qxng019s7y17hp_kgkzy9b180000gn/T/ipykernel_55914/2681262227.py:9: RuntimeWarning: overflow encountered in expm1
#   Bnu = 2 * h * nu**3 / c**2 / np.expm1(xx)

# %%
n = 400

prefix_sums = [0 for _ in range(n)] # theta_rms from gamma_jp to gamma_j = np.sqrt(prefix[j] - prefix[jp+1])

for j in range(n-1, -1, -1):
    all_int = 0
    factors = Jnu / nu**3 * dnu # <-- updated C.M.H.
    for k in range(nstep):
        all_int += compton_FF(2 * gamma_e_arr[j] * h * nu[k] / m_e / c**2) * factors[k]

    tp2 = 135 * m_e * c**2 / 128 / np.pi**4 / gamma_e_arr[j]**3 * (m_e * c**2 / kB / T_CMB)**4 * all_int
    sumi = tp2 / (m_e * c * gamma_e_arr[j])**2 * np.log(gamma_e_arr[1] / gamma_e_arr[0])

    prefix_sums[j] = sumi

    if j + 1 < n:
        prefix_sums[j] += prefix_sums[j + 1]
    print('prefix_sums[{:3d}]={:12.5E} thetarms={:12.5E} at E={:12.5E} eV'.format(j,prefix_sums[j],prefix_sums[j]**.5,gamma_e_arr[j]*5.11e5)) # <-- C.M.H. inserted
        
np.save("prefix_sums_new.npy", prefix_sums)
# Out:
# prefix_sums[399]= 7.15474E-20 thetarms= 2.67483E-10 at E= 9.99967E+13 eV
# prefix_sums[398]= 1.48623E-19 thetarms= 3.85517E-10 at E= 9.65935E+13 eV
# prefix_sums[397]= 2.31626E-19 thetarms= 4.81276E-10 at E= 9.33062E+13 eV
# prefix_sums[396]= 3.20980E-19 thetarms= 5.66551E-10 at E= 9.01307E+13 eV
# prefix_sums[395]= 4.17137E-19 thetarms= 6.45861E-10 at E= 8.70633E+13 eV
# prefix_sums[394]= 5.20577E-19 thetarms= 7.21511E-10 at E= 8.41003E+13 eV
# prefix_sums[393]= 6.31814E-19 thetarms= 7.94868E-10 at E= 8.12381E+13 eV
# prefix_sums[392]= 7.51393E-19 thetarms= 8.66829E-10 at E= 7.84734E+13 eV
# prefix_sums[391]= 8.79891E-19 thetarms= 9.38025E-10 at E= 7.58027E+13 eV
# prefix_sums[390]= 1.01793E-18 thetarms= 1.00892E-09 at E= 7.32229E+13 eV
# prefix_sums[389]= 1.16615E-18 thetarms= 1.07989E-09 at E= 7.07310E+13 eV
# prefix_sums[388]= 1.32526E-18 thetarms= 1.15120E-09 at E= 6.83238E+13 eV
# prefix_sums[387]= 1.49600E-18 thetarms= 1.22311E-09 at E= 6.59986E+13 eV
# prefix_sums[386]= 1.67914E-18 thetarms= 1.29582E-09 at E= 6.37524E+13 eV
# prefix_sums[385]= 1.87552E-18 thetarms= 1.36950E-09 at E= 6.15828E+13 eV
# prefix_sums[384]= 2.08601E-18 thetarms= 1.44430E-09 at E= 5.94869E+13 eV
# prefix_sums[383]= 2.31155E-18 thetarms= 1.52038E-09 at E= 5.74624E+13 eV
# prefix_sums[382]= 2.55313E-18 thetarms= 1.59785E-09 at E= 5.55068E+13 eV
# prefix_sums[381]= 2.81179E-18 thetarms= 1.67684E-09 at E= 5.36178E+13 eV
# prefix_sums[380]= 3.08864E-18 thetarms= 1.75745E-09 at E= 5.17930E+13 eV
# prefix_sums[379]= 3.38485E-18 thetarms= 1.83980E-09 at E= 5.00304E+13 eV
# prefix_sums[378]= 3.70165E-18 thetarms= 1.92397E-09 at E= 4.83277E+13 eV
# prefix_sums[377]= 4.04035E-18 thetarms= 2.01006E-09 at E= 4.66830E+13 eV
# prefix_sums[376]= 4.40234E-18 thetarms= 2.09818E-09 at E= 4.50942E+13 eV
# prefix_sums[375]= 4.78907E-18 thetarms= 2.18839E-09 at E= 4.35595E+13 eV
# prefix_sums[374]= 5.20208E-18 thetarms= 2.28081E-09 at E= 4.20771E+13 eV
# prefix_sums[373]= 5.64299E-18 thetarms= 2.37550E-09 at E= 4.06451E+13 eV
# prefix_sums[372]= 6.11351E-18 thetarms= 2.47255E-09 at E= 3.92618E+13 eV
# prefix_sums[371]= 6.61545E-18 thetarms= 2.57205E-09 at E= 3.79256E+13 eV
# prefix_sums[370]= 7.15071E-18 thetarms= 2.67408E-09 at E= 3.66349E+13 eV
# prefix_sums[369]= 7.72128E-18 thetarms= 2.77872E-09 at E= 3.53881E+13 eV
# prefix_sums[368]= 8.32927E-18 thetarms= 2.88605E-09 at E= 3.41838E+13 eV
# prefix_sums[367]= 8.97690E-18 thetarms= 2.99615E-09 at E= 3.30204E+13 eV
# prefix_sums[366]= 9.66649E-18 thetarms= 3.10910E-09 at E= 3.18966E+13 eV
# prefix_sums[365]= 1.04005E-17 thetarms= 3.22498E-09 at E= 3.08111E+13 eV
# prefix_sums[364]= 1.11815E-17 thetarms= 3.34387E-09 at E= 2.97625E+13 eV
# prefix_sums[363]= 1.20122E-17 thetarms= 3.46586E-09 at E= 2.87496E+13 eV
# prefix_sums[362]= 1.28953E-17 thetarms= 3.59101E-09 at E= 2.77712E+13 eV
# prefix_sums[361]= 1.38340E-17 thetarms= 3.71941E-09 at E= 2.68261E+13 eV
# prefix_sums[360]= 1.48313E-17 thetarms= 3.85115E-09 at E= 2.59131E+13 eV
# prefix_sums[359]= 1.58905E-17 thetarms= 3.98629E-09 at E= 2.50312E+13 eV
# prefix_sums[358]= 1.70150E-17 thetarms= 4.12492E-09 at E= 2.41793E+13 eV
# prefix_sums[357]= 1.82083E-17 thetarms= 4.26712E-09 at E= 2.33564E+13 eV
# prefix_sums[356]= 1.94744E-17 thetarms= 4.41298E-09 at E= 2.25616E+13 eV
# prefix_sums[355]= 2.08170E-17 thetarms= 4.56256E-09 at E= 2.17937E+13 eV
# prefix_sums[354]= 2.22403E-17 thetarms= 4.71596E-09 at E= 2.10520E+13 eV
# prefix_sums[353]= 2.37486E-17 thetarms= 4.87325E-09 at E= 2.03356E+13 eV
# prefix_sums[352]= 2.53464E-17 thetarms= 5.03452E-09 at E= 1.96435E+13 eV
# prefix_sums[351]= 2.70384E-17 thetarms= 5.19985E-09 at E= 1.89750E+13 eV
# prefix_sums[350]= 2.88296E-17 thetarms= 5.36932E-09 at E= 1.83292E+13 eV
# prefix_sums[349]= 3.07249E-17 thetarms= 5.54300E-09 at E= 1.77054E+13 eV
# prefix_sums[348]= 3.27298E-17 thetarms= 5.72100E-09 at E= 1.71028E+13 eV
# prefix_sums[347]= 3.48499E-17 thetarms= 5.90338E-09 at E= 1.65208E+13 eV
# prefix_sums[346]= 3.70909E-17 thetarms= 6.09023E-09 at E= 1.59585E+13 eV
# prefix_sums[345]= 3.94590E-17 thetarms= 6.28164E-09 at E= 1.54154E+13 eV
# prefix_sums[344]= 4.19605E-17 thetarms= 6.47769E-09 at E= 1.48908E+13 eV
# prefix_sums[343]= 4.46019E-17 thetarms= 6.67847E-09 at E= 1.43840E+13 eV
# prefix_sums[342]= 4.73901E-17 thetarms= 6.88405E-09 at E= 1.38945E+13 eV
# prefix_sums[341]= 5.03323E-17 thetarms= 7.09453E-09 at E= 1.34216E+13 eV
# prefix_sums[340]= 5.34359E-17 thetarms= 7.30998E-09 at E= 1.29649E+13 eV
# prefix_sums[339]= 5.67085E-17 thetarms= 7.53051E-09 at E= 1.25236E+13 eV
# prefix_sums[338]= 6.01584E-17 thetarms= 7.75618E-09 at E= 1.20974E+13 eV
# prefix_sums[337]= 6.37938E-17 thetarms= 7.98710E-09 at E= 1.16857E+13 eV
# prefix_sums[336]= 6.76234E-17 thetarms= 8.22334E-09 at E= 1.12880E+13 eV
# prefix_sums[335]= 7.16563E-17 thetarms= 8.46500E-09 at E= 1.09038E+13 eV
# prefix_sums[334]= 7.59018E-17 thetarms= 8.71216E-09 at E= 1.05328E+13 eV
# prefix_sums[333]= 8.03698E-17 thetarms= 8.96492E-09 at E= 1.01743E+13 eV
# prefix_sums[332]= 8.50703E-17 thetarms= 9.22335E-09 at E= 9.82804E+12 eV
# prefix_sums[331]= 9.00138E-17 thetarms= 9.48756E-09 at E= 9.49356E+12 eV
# prefix_sums[330]= 9.52113E-17 thetarms= 9.75763E-09 at E= 9.17047E+12 eV
# prefix_sums[329]= 1.00674E-16 thetarms= 1.00337E-08 at E= 8.85837E+12 eV
# prefix_sums[328]= 1.06414E-16 thetarms= 1.03157E-08 at E= 8.55690E+12 eV
# prefix_sums[327]= 1.12443E-16 thetarms= 1.06039E-08 at E= 8.26568E+12 eV
# prefix_sums[326]= 1.18774E-16 thetarms= 1.08984E-08 at E= 7.98438E+12 eV
# prefix_sums[325]= 1.25420E-16 thetarms= 1.11991E-08 at E= 7.71265E+12 eV
# prefix_sums[324]= 1.32395E-16 thetarms= 1.15063E-08 at E= 7.45017E+12 eV
# prefix_sums[323]= 1.39712E-16 thetarms= 1.18200E-08 at E= 7.19662E+12 eV
# prefix_sums[322]= 1.47387E-16 thetarms= 1.21403E-08 at E= 6.95170E+12 eV
# prefix_sums[321]= 1.55434E-16 thetarms= 1.24673E-08 at E= 6.71511E+12 eV
# prefix_sums[320]= 1.63869E-16 thetarms= 1.28011E-08 at E= 6.48658E+12 eV
# prefix_sums[319]= 1.72708E-16 thetarms= 1.31419E-08 at E= 6.26582E+12 eV
# prefix_sums[318]= 1.81969E-16 thetarms= 1.34896E-08 at E= 6.05258E+12 eV
# prefix_sums[317]= 1.91668E-16 thetarms= 1.38444E-08 at E= 5.84659E+12 eV
# prefix_sums[316]= 2.01824E-16 thetarms= 1.42065E-08 at E= 5.64762E+12 eV
# prefix_sums[315]= 2.12455E-16 thetarms= 1.45758E-08 at E= 5.45541E+12 eV
# prefix_sums[314]= 2.23581E-16 thetarms= 1.49526E-08 at E= 5.26975E+12 eV
# prefix_sums[313]= 2.35222E-16 thetarms= 1.53369E-08 at E= 5.09041E+12 eV
# prefix_sums[312]= 2.47398E-16 thetarms= 1.57289E-08 at E= 4.91717E+12 eV
# prefix_sums[311]= 2.60131E-16 thetarms= 1.61286E-08 at E= 4.74982E+12 eV
# prefix_sums[310]= 2.73443E-16 thetarms= 1.65361E-08 at E= 4.58817E+12 eV
# prefix_sums[309]= 2.87358E-16 thetarms= 1.69516E-08 at E= 4.43202E+12 eV
# prefix_sums[308]= 3.01899E-16 thetarms= 1.73752E-08 at E= 4.28119E+12 eV
# prefix_sums[307]= 3.17090E-16 thetarms= 1.78070E-08 at E= 4.13549E+12 eV
# prefix_sums[306]= 3.32957E-16 thetarms= 1.82471E-08 at E= 3.99475E+12 eV
# prefix_sums[305]= 3.49527E-16 thetarms= 1.86957E-08 at E= 3.85880E+12 eV
# prefix_sums[304]= 3.66828E-16 thetarms= 1.91527E-08 at E= 3.72747E+12 eV
# prefix_sums[303]= 3.84886E-16 thetarms= 1.96185E-08 at E= 3.60061E+12 eV
# prefix_sums[302]= 4.03732E-16 thetarms= 2.00931E-08 at E= 3.47807E+12 eV
# prefix_sums[301]= 4.23396E-16 thetarms= 2.05766E-08 at E= 3.35971E+12 eV
# prefix_sums[300]= 4.43909E-16 thetarms= 2.10692E-08 at E= 3.24537E+12 eV
# prefix_sums[299]= 4.65304E-16 thetarms= 2.15709E-08 at E= 3.13492E+12 eV
# prefix_sums[298]= 4.87615E-16 thetarms= 2.20820E-08 at E= 3.02823E+12 eV
# prefix_sums[297]= 5.10875E-16 thetarms= 2.26026E-08 at E= 2.92517E+12 eV
# prefix_sums[296]= 5.35122E-16 thetarms= 2.31327E-08 at E= 2.82562E+12 eV
# prefix_sums[295]= 5.60392E-16 thetarms= 2.36726E-08 at E= 2.72945E+12 eV
# prefix_sums[294]= 5.86725E-16 thetarms= 2.42224E-08 at E= 2.63656E+12 eV
# prefix_sums[293]= 6.14159E-16 thetarms= 2.47822E-08 at E= 2.54683E+12 eV
# prefix_sums[292]= 6.42736E-16 thetarms= 2.53522E-08 at E= 2.46016E+12 eV
# prefix_sums[291]= 6.72500E-16 thetarms= 2.59326E-08 at E= 2.37643E+12 eV
# prefix_sums[290]= 7.03494E-16 thetarms= 2.65235E-08 at E= 2.29556E+12 eV
# prefix_sums[289]= 7.35764E-16 thetarms= 2.71250E-08 at E= 2.21743E+12 eV
# prefix_sums[225]= 9.75173E-15 thetarms= 9.87508E-08 at E= 2.41793E+11 eV
# prefix_sums[224]= 1.01294E-14 thetarms= 1.00645E-07 at E= 2.33564E+11 eV
# prefix_sums[223]= 1.05216E-14 thetarms= 1.02575E-07 at E= 2.25616E+11 eV
# prefix_sums[222]= 1.09289E-14 thetarms= 1.04541E-07 at E= 2.17937E+11 eV
# prefix_sums[221]= 1.13518E-14 thetarms= 1.06545E-07 at E= 2.10520E+11 eV
# prefix_sums[220]= 1.17911E-14 thetarms= 1.08587E-07 at E= 2.03356E+11 eV
# prefix_sums[219]= 1.22474E-14 thetarms= 1.10668E-07 at E= 1.96435E+11 eV
# prefix_sums[218]= 1.27214E-14 thetarms= 1.12789E-07 at E= 1.89750E+11 eV
# prefix_sums[217]= 1.32138E-14 thetarms= 1.14951E-07 at E= 1.83292E+11 eV
# prefix_sums[216]= 1.37253E-14 thetarms= 1.17155E-07 at E= 1.77054E+11 eV
# prefix_sums[215]= 1.42568E-14 thetarms= 1.19402E-07 at E= 1.71028E+11 eV
# prefix_sums[214]= 1.48090E-14 thetarms= 1.21692E-07 at E= 1.65208E+11 eV
# prefix_sums[213]= 1.53829E-14 thetarms= 1.24028E-07 at E= 1.59585E+11 eV
# prefix_sums[212]= 1.59794E-14 thetarms= 1.26410E-07 at E= 1.54154E+11 eV
# prefix_sums[211]= 1.65993E-14 thetarms= 1.28838E-07 at E= 1.48908E+11 eV
# prefix_sums[210]= 1.72437E-14 thetarms= 1.31315E-07 at E= 1.43840E+11 eV
# prefix_sums[209]= 1.79136E-14 thetarms= 1.33842E-07 at E= 1.38945E+11 eV
# prefix_sums[208]= 1.86100E-14 thetarms= 1.36419E-07 at E= 1.34216E+11 eV
# prefix_sums[207]= 1.93342E-14 thetarms= 1.39048E-07 at E= 1.29649E+11 eV
# prefix_sums[206]= 2.00873E-14 thetarms= 1.41730E-07 at E= 1.25236E+11 eV
# prefix_sums[205]= 2.08704E-14 thetarms= 1.44466E-07 at E= 1.20974E+11 eV
# prefix_sums[204]= 2.16850E-14 thetarms= 1.47258E-07 at E= 1.16857E+11 eV
# prefix_sums[203]= 2.25324E-14 thetarms= 1.50108E-07 at E= 1.12880E+11 eV
# prefix_sums[202]= 2.34139E-14 thetarms= 1.53016E-07 at E= 1.09038E+11 eV
# prefix_sums[201]= 2.43311E-14 thetarms= 1.55984E-07 at E= 1.05328E+11 eV
# prefix_sums[200]= 2.52855E-14 thetarms= 1.59014E-07 at E= 1.01743E+11 eV
# prefix_sums[199]= 2.62787E-14 thetarms= 1.62107E-07 at E= 9.82804E+10 eV
# prefix_sums[198]= 2.73125E-14 thetarms= 1.65265E-07 at E= 9.49356E+10 eV
# prefix_sums[197]= 2.83886E-14 thetarms= 1.68489E-07 at E= 9.17047E+10 eV
# prefix_sums[196]= 2.95088E-14 thetarms= 1.71781E-07 at E= 8.85837E+10 eV
# prefix_sums[195]= 3.06753E-14 thetarms= 1.75144E-07 at E= 8.55690E+10 eV
# prefix_sums[194]= 3.18899E-14 thetarms= 1.78577E-07 at E= 8.26568E+10 eV
# prefix_sums[193]= 3.31548E-14 thetarms= 1.82085E-07 at E= 7.98438E+10 eV
# prefix_sums[192]= 3.44723E-14 thetarms= 1.85667E-07 at E= 7.71265E+10 eV
# prefix_sums[191]= 3.58447E-14 thetarms= 1.89327E-07 at E= 7.45017E+10 eV
# prefix_sums[190]= 3.72745E-14 thetarms= 1.93066E-07 at E= 7.19662E+10 eV
# prefix_sums[189]= 3.87643E-14 thetarms= 1.96887E-07 at E= 6.95170E+10 eV
# prefix_sums[188]= 4.03168E-14 thetarms= 2.00790E-07 at E= 6.71511E+10 eV
# prefix_sums[187]= 4.19347E-14 thetarms= 2.04780E-07 at E= 6.48658E+10 eV
# prefix_sums[186]= 4.36212E-14 thetarms= 2.08857E-07 at E= 6.26582E+10 eV
# prefix_sums[185]= 4.53792E-14 thetarms= 2.13024E-07 at E= 6.05258E+10 eV
# prefix_sums[184]= 4.72121E-14 thetarms= 2.17283E-07 at E= 5.84659E+10 eV
# prefix_sums[183]= 4.91232E-14 thetarms= 2.21637E-07 at E= 5.64762E+10 eV
# prefix_sums[182]= 5.11161E-14 thetarms= 2.26089E-07 at E= 5.45541E+10 eV
# prefix_sums[181]= 5.31946E-14 thetarms= 2.30640E-07 at E= 5.26975E+10 eV
# prefix_sums[180]= 5.53626E-14 thetarms= 2.35293E-07 at E= 5.09041E+10 eV
# prefix_sums[179]= 5.76241E-14 thetarms= 2.40050E-07 at E= 4.91717E+10 eV
# prefix_sums[178]= 5.99836E-14 thetarms= 2.44916E-07 at E= 4.74982E+10 eV
# prefix_sums[177]= 6.24455E-14 thetarms= 2.49891E-07 at E= 4.58817E+10 eV
# prefix_sums[176]= 6.50145E-14 thetarms= 2.54979E-07 at E= 4.43202E+10 eV
# prefix_sums[175]= 6.76955E-14 thetarms= 2.60184E-07 at E= 4.28119E+10 eV
# prefix_sums[174]= 7.04938E-14 thetarms= 2.65507E-07 at E= 4.13549E+10 eV
# prefix_sums[173]= 7.34147E-14 thetarms= 2.70952E-07 at E= 3.99475E+10 eV
# prefix_sums[172]= 7.64640E-14 thetarms= 2.76521E-07 at E= 3.85880E+10 eV
# prefix_sums[171]= 7.96475E-14 thetarms= 2.82219E-07 at E= 3.72747E+10 eV
# prefix_sums[170]= 8.29715E-14 thetarms= 2.88048E-07 at E= 3.60061E+10 eV
# prefix_sums[169]= 8.64424E-14 thetarms= 2.94011E-07 at E= 3.47807E+10 eV
# prefix_sums[168]= 9.00671E-14 thetarms= 3.00112E-07 at E= 3.35971E+10 eV
# prefix_sums[167]= 9.38528E-14 thetarms= 3.06354E-07 at E= 3.24537E+10 eV
# prefix_sums[166]= 9.78068E-14 thetarms= 3.12741E-07 at E= 3.13492E+10 eV
# prefix_sums[165]= 1.01937E-13 thetarms= 3.19276E-07 at E= 3.02823E+10 eV
# prefix_sums[164]= 1.06251E-13 thetarms= 3.25962E-07 at E= 2.92517E+10 eV
# prefix_sums[163]= 1.10759E-13 thetarms= 3.32804E-07 at E= 2.82562E+10 eV
# prefix_sums[162]= 1.15468E-13 thetarms= 3.39805E-07 at E= 2.72945E+10 eV
# prefix_sums[161]= 1.20388E-13 thetarms= 3.46969E-07 at E= 2.63656E+10 eV
# prefix_sums[160]= 1.25529E-13 thetarms= 3.54300E-07 at E= 2.54683E+10 eV
# prefix_sums[159]= 1.30901E-13 thetarms= 3.61802E-07 at E= 2.46016E+10 eV
# prefix_sums[158]= 1.36514E-13 thetarms= 3.69478E-07 at E= 2.37643E+10 eV
# prefix_sums[157]= 1.42381E-13 thetarms= 3.77334E-07 at E= 2.29556E+10 eV
# prefix_sums[156]= 1.48512E-13 thetarms= 3.85372E-07 at E= 2.21743E+10 eV
# prefix_sums[155]= 1.54919E-13 thetarms= 3.93598E-07 at E= 2.14197E+10 eV
# prefix_sums[154]= 1.61616E-13 thetarms= 4.02015E-07 at E= 2.06907E+10 eV
# prefix_sums[153]= 1.68615E-13 thetarms= 4.10628E-07 at E= 1.99865E+10 eV
# prefix_sums[152]= 1.75931E-13 thetarms= 4.19441E-07 at E= 1.93063E+10 eV
# prefix_sums[151]= 1.83578E-13 thetarms= 4.28460E-07 at E= 1.86493E+10 eV
# prefix_sums[150]= 1.91570E-13 thetarms= 4.37687E-07 at E= 1.80146E+10 eV
# prefix_sums[149]= 1.99924E-13 thetarms= 4.47129E-07 at E= 1.74015E+10 eV
# prefix_sums[148]= 2.08656E-13 thetarms= 4.56789E-07 at E= 1.68093E+10 eV
# prefix_sums[147]= 2.17784E-13 thetarms= 4.66673E-07 at E= 1.62372E+10 eV
# prefix_sums[146]= 2.27324E-13 thetarms= 4.76785E-07 at E= 1.56846E+10 eV
# prefix_sums[145]= 2.37297E-13 thetarms= 4.87131E-07 at E= 1.51508E+10 eV
# prefix_sums[144]= 2.47720E-13 thetarms= 4.97715E-07 at E= 1.46352E+10 eV
# prefix_sums[143]= 2.58615E-13 thetarms= 5.08542E-07 at E= 1.41371E+10 eV
# prefix_sums[142]= 2.70002E-13 thetarms= 5.19618E-07 at E= 1.36560E+10 eV
# prefix_sums[141]= 2.81904E-13 thetarms= 5.30947E-07 at E= 1.31913E+10 eV
# prefix_sums[140]= 2.94344E-13 thetarms= 5.42535E-07 at E= 1.27423E+10 eV
# prefix_sums[139]= 3.07345E-13 thetarms= 5.54387E-07 at E= 1.23087E+10 eV
# prefix_sums[138]= 3.20932E-13 thetarms= 5.66509E-07 at E= 1.18898E+10 eV
# prefix_sums[137]= 3.35131E-13 thetarms= 5.78905E-07 at E= 1.14851E+10 eV
# prefix_sums[136]= 3.49970E-13 thetarms= 5.91583E-07 at E= 1.10943E+10 eV
# prefix_sums[135]= 3.65476E-13 thetarms= 6.04546E-07 at E= 1.07167E+10 eV
# prefix_sums[134]= 3.81678E-13 thetarms= 6.17801E-07 at E= 1.03520E+10 eV
# prefix_sums[133]= 3.98608E-13 thetarms= 6.31354E-07 at E= 9.99967E+09 eV
# prefix_sums[132]= 4.16296E-13 thetarms= 6.45210E-07 at E= 9.65935E+09 eV
# prefix_sums[131]= 4.34775E-13 thetarms= 6.59375E-07 at E= 9.33062E+09 eV
# prefix_sums[130]= 4.54081E-13 thetarms= 6.73855E-07 at E= 9.01307E+09 eV
# prefix_sums[129]= 4.74248E-13 thetarms= 6.88656E-07 at E= 8.70633E+09 eV
# prefix_sums[128]= 4.95313E-13 thetarms= 7.03785E-07 at E= 8.41003E+09 eV
# prefix_sums[127]= 5.17316E-13 thetarms= 7.19247E-07 at E= 8.12381E+09 eV
# prefix_sums[126]= 5.40295E-13 thetarms= 7.35048E-07 at E= 7.84734E+09 eV
# prefix_sums[125]= 5.64293E-13 thetarms= 7.51195E-07 at E= 7.58027E+09 eV
# prefix_sums[124]= 5.89353E-13 thetarms= 7.67694E-07 at E= 7.32229E+09 eV
# prefix_sums[123]= 6.15520E-13 thetarms= 7.84551E-07 at E= 7.07310E+09 eV
# prefix_sums[122]= 6.42841E-13 thetarms= 8.01774E-07 at E= 6.83238E+09 eV
# prefix_sums[121]= 6.71363E-13 thetarms= 8.19368E-07 at E= 6.59986E+09 eV
# prefix_sums[120]= 7.01138E-13 thetarms= 8.37340E-07 at E= 6.37524E+09 eV
# prefix_sums[119]= 7.32218E-13 thetarms= 8.55697E-07 at E= 6.15828E+09 eV
# prefix_sums[118]= 7.64657E-13 thetarms= 8.74447E-07 at E= 5.94869E+09 eV
# prefix_sums[117]= 7.98511E-13 thetarms= 8.93594E-07 at E= 5.74624E+09 eV
# prefix_sums[116]= 8.33839E-13 thetarms= 9.13148E-07 at E= 5.55068E+09 eV
# prefix_sums[115]= 8.70701E-13 thetarms= 9.33114E-07 at E= 5.36178E+09 eV
# prefix_sums[114]= 9.09161E-13 thetarms= 9.53499E-07 at E= 5.17930E+09 eV
# prefix_sums[113]= 9.49285E-13 thetarms= 9.74312E-07 at E= 5.00304E+09 eV
# prefix_sums[112]= 9.91139E-13 thetarms= 9.95560E-07 at E= 4.83277E+09 eV
# prefix_sums[111]= 1.03479E-12 thetarms= 1.01725E-06 at E= 4.66830E+09 eV
# prefix_sums[110]= 1.08033E-12 thetarms= 1.03939E-06 at E= 4.50942E+09 eV
# prefix_sums[109]= 1.12781E-12 thetarms= 1.06198E-06 at E= 4.35595E+09 eV
# prefix_sums[108]= 1.17732E-12 thetarms= 1.08504E-06 at E= 4.20771E+09 eV
# prefix_sums[107]= 1.22894E-12 thetarms= 1.10857E-06 at E= 4.06451E+09 eV
# prefix_sums[106]= 1.28275E-12 thetarms= 1.13259E-06 at E= 3.92618E+09 eV
# prefix_sums[105]= 1.33885E-12 thetarms= 1.15709E-06 at E= 3.79256E+09 eV
# prefix_sums[104]= 1.39733E-12 thetarms= 1.18209E-06 at E= 3.66349E+09 eV
# prefix_sums[103]= 1.45827E-12 thetarms= 1.20759E-06 at E= 3.53881E+09 eV
# prefix_sums[102]= 1.52178E-12 thetarms= 1.23360E-06 at E= 3.41838E+09 eV
# prefix_sums[101]= 1.58796E-12 thetarms= 1.26014E-06 at E= 3.30204E+09 eV
# prefix_sums[100]= 1.65691E-12 thetarms= 1.28721E-06 at E= 3.18966E+09 eV
# prefix_sums[ 99]= 1.72874E-12 thetarms= 1.31482E-06 at E= 3.08111E+09 eV
# prefix_sums[ 98]= 1.80357E-12 thetarms= 1.34297E-06 at E= 2.97625E+09 eV
# prefix_sums[ 97]= 1.88152E-12 thetarms= 1.37169E-06 at E= 2.87496E+09 eV
# prefix_sums[ 96]= 1.96270E-12 thetarms= 1.40096E-06 at E= 2.77712E+09 eV
# prefix_sums[ 95]= 2.04725E-12 thetarms= 1.43082E-06 at E= 2.68261E+09 eV
# prefix_sums[ 94]= 2.13529E-12 thetarms= 1.46126E-06 at E= 2.59131E+09 eV
# prefix_sums[ 93]= 2.22696E-12 thetarms= 1.49230E-06 at E= 2.50312E+09 eV
# prefix_sums[ 92]= 2.32240E-12 thetarms= 1.52394E-06 at E= 2.41793E+09 eV
# prefix_sums[ 91]= 2.42176E-12 thetarms= 1.55620E-06 at E= 2.33564E+09 eV
# prefix_sums[ 90]= 2.52518E-12 thetarms= 1.58908E-06 at E= 2.25616E+09 eV
# prefix_sums[ 89]= 2.63284E-12 thetarms= 1.62260E-06 at E= 2.17937E+09 eV
# prefix_sums[ 88]= 2.74489E-12 thetarms= 1.65677E-06 at E= 2.10520E+09 eV
# prefix_sums[ 87]= 2.86149E-12 thetarms= 1.69159E-06 at E= 2.03356E+09 eV
# prefix_sums[ 86]= 2.98284E-12 thetarms= 1.72709E-06 at E= 1.96435E+09 eV
# prefix_sums[ 85]= 3.10910E-12 thetarms= 1.76326E-06 at E= 1.89750E+09 eV
# prefix_sums[ 84]= 3.24047E-12 thetarms= 1.80013E-06 at E= 1.83292E+09 eV
# prefix_sums[ 83]= 3.37715E-12 thetarms= 1.83770E-06 at E= 1.77054E+09 eV
# prefix_sums[ 82]= 3.51934E-12 thetarms= 1.87599E-06 at E= 1.71028E+09 eV
# prefix_sums[ 81]= 3.66725E-12 thetarms= 1.91501E-06 at E= 1.65208E+09 eV
# prefix_sums[ 80]= 3.82111E-12 thetarms= 1.95477E-06 at E= 1.59585E+09 eV
# prefix_sums[ 79]= 3.98114E-12 thetarms= 1.99528E-06 at E= 1.54154E+09 eV
# prefix_sums[ 78]= 4.14757E-12 thetarms= 2.03656E-06 at E= 1.48908E+09 eV
# prefix_sums[ 77]= 4.32067E-12 thetarms= 2.07862E-06 at E= 1.43840E+09 eV
# prefix_sums[ 76]= 4.50067E-12 thetarms= 2.12148E-06 at E= 1.38945E+09 eV
# prefix_sums[ 75]= 4.68785E-12 thetarms= 2.16515E-06 at E= 1.34216E+09 eV
# prefix_sums[ 74]= 4.88249E-12 thetarms= 2.20964E-06 at E= 1.29649E+09 eV
# prefix_sums[ 73]= 5.08488E-12 thetarms= 2.25497E-06 at E= 1.25236E+09 eV
# prefix_sums[ 72]= 5.29530E-12 thetarms= 2.30115E-06 at E= 1.20974E+09 eV
# prefix_sums[ 11]= 6.12289E-11 thetarms= 7.82489E-06 at E= 1.46352E+08 eV
# prefix_sums[ 10]= 6.38879E-11 thetarms= 7.99299E-06 at E= 1.41371E+08 eV
# prefix_sums[  9]= 6.66768E-11 thetarms= 8.16559E-06 at E= 1.36560E+08 eV
# prefix_sums[  8]= 6.96033E-11 thetarms= 8.34286E-06 at E= 1.31913E+08 eV
# prefix_sums[  7]= 7.26754E-11 thetarms= 8.52499E-06 at E= 1.27423E+08 eV
# prefix_sums[  6]= 7.59018E-11 thetarms= 8.71216E-06 at E= 1.23087E+08 eV
# prefix_sums[  5]= 7.92917E-11 thetarms= 8.90459E-06 at E= 1.18898E+08 eV
# prefix_sums[  4]= 8.28551E-11 thetarms= 9.10248E-06 at E= 1.14851E+08 eV
# prefix_sums[  3]= 8.66024E-11 thetarms= 9.30604E-06 at E= 1.10943E+08 eV
# prefix_sums[  2]= 9.05451E-11 thetarms= 9.51552E-06 at E= 1.07167E+08 eV
# prefix_sums[  1]= 9.46953E-11 thetarms= 9.73115E-06 at E= 1.03520E+08 eV
# prefix_sums[  0]= 9.90660E-11 thetarms= 9.95319E-06 at E= 9.99967E+07 eV

# %%
print(prefix_sums[0], prefix_sums[-1])
# Out:
# 9.9066004556493e-11 7.154739952002411e-20

# %% [markdown]
# ### read theta_rms directly

# %%
prefix_sums = np.load("prefix_sums_new.npy")
print(prefix_sums[0], prefix_sums[-1])
# Out:
# 9.9066004556493e-11 7.154739952002411e-20

# %%
def calculate_solid_angles(theta):
    # theta_half[i] = theta[i-1/2]
    theta_half = (theta[1:] + theta[:-1]) / 2
    theta_half = np.concatenate([[theta[0]/2], theta_half, [3*theta[-1]/2 - theta[-2]/2]])

    Omega = 2 * np.pi * (theta_half[2:]**2 - theta_half[:-2]**2) / 2  # solid angles of annulus
    Omega = np.concatenate([Omega, [2 * np.pi * (theta[-1]**2 - theta_half[-2]**2)]])  # add the last circle

    return Omega, theta_half

# %%
Omega, theta_half = calculate_solid_angles(theta_e_arr)

# %%
M = np.zeros((400, 400))

for i in range(400):
    for j in range(400):
        if j == i + 1:
            M[i, j] = -2 * np.pi / Omega[i] * theta_half[i+1] / (theta_e_arr[i+1] - theta_e_arr[i])
        if j == i - 1:
            M[i, j] = -2 * np.pi / Omega[i] * theta_half[i] / (theta_e_arr[i] - theta_e_arr[i-1])
for i in range(1,399):
    M[i, i] = 2 * np.pi / Omega[i] * (theta_half[i+1] / (theta_e_arr[i+1] - theta_e_arr[i]) + theta_half[i] / (theta_e_arr[i] - theta_e_arr[i-1]))

#M[0, 0] = 0
#M[-1, -1] = 0

M[0,0] = -M[1,0]*Omega[1]/Omega[0]
M[-1,-1] = -M[-2,-1]*Omega[-2]/Omega[-1]
#fits.PrimaryHDU(M).writeto('M-matrix_new.fits', overwrite=True)

# %% [markdown]
# ### new element of columb

# %%
F_NP = np.loadtxt('fnpk_z2_new.dat')
k_prep = F_NP[:, 0]
fnpk = F_NP[:, 1]
plt.plot(k_prep, fnpk)
plt.xscale('log')
plt.show()

# %%
print(max(fnpk))
# Out:
# 1.9013292305894944

# %%
dk = np.array([F_NP[:, 0][i] - F_NP[:, 0][i-1] for i in range(1, 301)])
dk = np.insert(dk, 0, 0)

k_cut = F_NP[:, 0][-1] # suppose

# %%
omega_b = omega_b_0 * (1 + z)**3
mean_n_b = 3 * omega_b * H_0 * H_0 / (8 * np.pi * G * m_p) # mean number density of baryons at the redshift
n_b = mean_n_b # for mean density
    
n_H = n_b * (1 - Y_He) # nuclei in hydrogen
n_He = n_H * f_He # nuclei in helium, assume He is all 4He

n_e = n_H + 2 * n_He # for fully ionized

# %%
# nsp = 3 # number of species
# mass_sp = np.array([m_e, m_p, 4*m_p]) # masses
# nth_sp = np.array([n_e,n_H,n_He]) # number densities
# Z_sp = np.array([-1.,1.,2.]) # charges

# Z_proj = 1
# #v_proj = c
# #p_proj = m_e * c

# def T(p_proj, v_proj, l):
#     #p_proj = m_e * c * gamma
#     #v_proj = c / gamma
#     co = 2 * np.pi * l**2 * Z_proj**2 * e**4 / (p_proj**2 * v_proj)
#     sum_nsp = 0
#     gamma_E = np.euler_gamma # Euler's constant
#     for a in range(nsp):
#         int_FNP = np.sum(dk * F_NP[:, 1] / F_NP[:, 0] + 1 - gamma_E - np.log(h/2/np.pi * k_cut * l / p_proj))
#         sum_isp = Z_sp[a]**2 * nth_sp[a] * int_FNP
#         sum_nsp += sum_isp
#     return co * sum_nsp

# %%
nsp = 3 # number of species
mass_sp = np.array([m_e, m_p, 4*m_p]) # masses
nth_sp = np.array([n_e,n_H,n_He]) # number densities
Z_sp = np.array([-1.,1.,2.]) # charges

Z_proj = 1

def T_vectorized(gamma, l): # eq 37
    p_proj = m_e * c * gamma
    v_proj = c / gamma
    co = 2 * np.pi * l**2 * Z_proj**2 * e**4 / (p_proj**2 * v_proj)
    
    ## vectorize
    gamma_E = np.euler_gamma # Euler's constant
    sum_nsp = np.zeros(gamma.shape) # Initialize sum_nsp as an array of zeros with the same shape as gamma
    
    for a in range(nsp):
        int_FNP = np.sum(dk * F_NP[:, 1] / F_NP[:, 0] + 1 - gamma_E - np.log(h/2/np.pi * k_cut * l / p_proj[:, np.newaxis]), axis=1)
        sum_isp = Z_sp[a]**2 * nth_sp[a] * int_FNP
        sum_nsp += sum_isp
    
    return co * sum_nsp

# %%
eigenvalues, eigenvectors = np.linalg.eig(M)

V = eigenvectors

A = np.diag(eigenvalues) # sqrt(A[i][i])

V_inv = np.linalg.inv(V)

#diagonalized_M = np.dot(np.dot(V, A), V_inv)

# print("Diagonalized Matrix:")
# print(diagonalized_M)

# %%
def T_ij(l, i ,j): # eq 39 bracket part
    Gamma_IC0 = 1.1e-18 * z2**4
    gamma_ij = gamma_e_arr[i:j+1]
    d_gamma_e = np.insert(np.diff(gamma_ij), 0, 0)
    Tl = T_vectorized(gamma_ij, l)
    #print(Tl.shape, d_gamma_e.shape, gamma_ij.shape)
    return -np.sum(Tl * d_gamma_e / Gamma_IC0 / gamma_ij**2)

# %%
def get_nij(i, j, t, M_expm): # nij = dN / (dV dgammae_j dOmegae_i)
    Gamma_IC0 = 1.1e-18 * z2**4
    gamma_max_inv = 1. / gamma_e_arr[j] - Gamma_IC0 * t
    if gamma_max_inv>1e-99:
        gamma_max = 1./gamma_max_inv
    else:
        gamma_max = 1e99
        
    nij = 0
    
    for jp in range(j, 399):
        if gamma_e_arr[jp] <= gamma_max:
            # THIS IS A COMMENT: rate_trans_smoothed = M_expm @ rate_trans
            # Then, rate_trans_smoothed[i][jp] is the dot product of M_expm[jp][i] and rate_trans[:, jp]
            rate_trans_smoothed_ijp = np.dot(M_expm[jp, i, :], rate_trans[:, jp])
                
            sum_ij = (gamma_e_arr[jp] - gamma_e_arr[jp-1]) * rate_trans_smoothed_ijp
            
            if gamma_e_arr[jp+1] > gamma_max:
                fraction = (gamma_max - gamma_e_arr[jp]) / (gamma_e_arr[jp+1] - gamma_e_arr[jp])
                sum_ij = sum_ij * fraction
            nij += sum_ij
    nij = nij / (Gamma_IC0 * gamma_e_arr[j]**2)
    return nij

# %%
def get_ni(i, nij): # integrate gamma_e (1/gamma_e) nij
    ni = 0
    for j in range(1, 400):
        sum_i = (gamma_e_arr[j] - gamma_e_arr[j-1]) / gamma_e_arr[j] * nij[i][j]
        ni += sum_i
    return ni

# %%
#t_arr = [1e8, 5e8, 1e9, 5e9, 1e10, 5e10, 1e11, 5e11, 1e12, 5e12, 1e13]
#t_arr = [1e8, 1e9, 1e10, 1e11, 1e12, 1e13] # To save time, I cut it short
t_arr = [1e9]
t_num = len(t_arr)

# %%
Omega_x = np.logspace(-8,0, 400).reshape(400, 1)

# %%
l = np.array([np.sqrt(A[i][i]) for i in range(len(A))])
#print(l)

# %%
T_ij(l[0], 0, 10)
# Out:
# -3.331656171314533e+55

# %% [markdown]
# ## Calculating nij consume several hours

# %%
nij = np.zeros((t_num, 400, 400))
time_start = time.time()
for k in range(t_num):
    print(f'time {k} {t_arr[k]:.1e}', end = ' ')
    
    for j in range(1, 400):
        print(f'j = {j}, time = {(time.time()-time_start)/60}')
        M_new = np.zeros((400, 400, 400))
        for jp in range(j, 399):
            theta_rms = np.sqrt(prefix_sums[j] - prefix_sums[jp+1]) # from jp to j
            M_expm = scipy.linalg.expm(-theta_rms**2/4 * M)
            
            ### new element for columb scattering
            new_EV = np.zeros((len(l)))
            for x in range(len(l)):
                new_EV[x] = np.exp(T_ij(l[x], j, jp)) # from jp to j, eq 39 exp part
            new_D = np.diag(new_EV)
            columb = np.dot(np.dot(V, new_D), V_inv)
            
            M_new[jp] = M_expm @ columb
            
            if np.isnan(M_new[jp,:,:].any()): print('test', j, jp, np.isnan(M_new[jp,:,:].any()))

        for i in range(400):
            nij[k][i][j-1] = get_nij(i, j, t_arr[k], M_new)
    print('t = ', (time.time() - time_start) / 60)
# Out:
# time 0 1.0e+09 j = 1, time = 5.817413330078125e-06
# j = 2, time = 1.417800533771515
# j = 3, time = 2.8628795663515727
# j = 4, time = 4.278390701611837
# j = 5, time = 5.70457501411438
# j = 366, time = 246.88906128406524
# j = 367, time = 246.945235200723
# j = 368, time = 246.99801119963328
# j = 369, time = 247.04978676637015
# j = 370, time = 247.09980638424557
# j = 371, time = 247.14820458491644
# j = 372, time = 247.19450470209122
# j = 373, time = 247.2397549510002
# j = 374, time = 247.28663586775463
# j = 375, time = 247.32675688266755
# j = 376, time = 247.3646947701772
# j = 377, time = 247.40232954819996
# j = 378, time = 247.4394999186198
# j = 379, time = 247.47517074743908
# j = 380, time = 247.5080855647723
# j = 381, time = 247.5377946972847
# j = 382, time = 247.56163770357767
# j = 383, time = 247.58762876590092
# j = 384, time = 247.60949740012487
# j = 385, time = 247.63147643407186
# j = 386, time = 247.65208605130513
# j = 387, time = 247.67078263362248
# j = 388, time = 247.68637468417487
# j = 389, time = 247.70230148235956
# j = 390, time = 247.71589010159175
# j = 391, time = 247.72829868396124
# j = 392, time = 247.739601735274
# j = 393, time = 247.74816773335138
# j = 394, time = 247.75767201979954
# j = 395, time = 247.7645600994428
# j = 396, time = 247.7706892331441
# j = 397, time = 247.77415213187535
# j = 398, time = 247.77663478453954
# j = 399, time = 247.7777231176694
# t =  247.77773558298748

# %%
## save data

fits.PrimaryHDU(nij).writeto('nij_new.fits', overwrite=True)

# %% [markdown]
# ## read nij directly

# %%
# read data
with fits.open('nij.fits') as hdul:
    nij = hdul[0].data # shape (t_num, theta, gamma)

# %%
print(nij)
# Out:
# [[[ 4.85113215e-31  5.34403368e-31  5.89377582e-31 ...  1.16381674e-30
#     0.00000000e+00  0.00000000e+00]
#   [ 4.85113215e-31  5.34403368e-31  5.89377582e-31 ...  9.75504556e-31
#     0.00000000e+00  0.00000000e+00]
#   [ 4.85113215e-31  5.34403368e-31  5.89377582e-31 ...  8.15998192e-31
#     0.00000000e+00  0.00000000e+00]
#   ...
#   [ 4.28341584e-45  3.81780809e-45  3.40206027e-45 ...  1.20188411e-59
#     0.00000000e+00  0.00000000e+00]
#   [ 3.15565176e-45  2.81257902e-45  2.50743922e-45 ... -1.51646058e-60
#     0.00000000e+00  0.00000000e+00]
#   [ 2.32666897e-45  2.07383795e-45  1.84917734e-45 ...  8.27888166e-60
#     0.00000000e+00  0.00000000e+00]]]

# %%
ni = np.zeros((t_num, 400)) # about theta
for k in range(t_num):
    for i in range(400):
        ni[k][i] = get_ni(i, nij[k])

# %%
mc = np.zeros((400, t_num+1))
mc[:,0] = theta_e_arr
mc[:,1:] = ni.T
#np.savetxt('ni.dat', mc)

# %%
deriv_array = np.zeros((400,t_num))
for j in range(399):
    for jp in range(j,399):
        if j==jp:
            tr = 0.
        else:
            tr = np.arccosh(theta_e_arr[jp]/theta_e_arr[j])
        deriv_array[j,:] += 2 * theta_e_arr[j] * (ni[:,jp+1]-ni[:,jp])/(theta_e_arr[jp+1]-theta_e_arr[jp])\
          * (np.arccosh(theta_e_arr[jp+1]/theta_e_arr[j]) - tr)
mc2 = np.zeros((400, t_num+1))
mc2[:,0] = theta_e_arr
mc2[:,1:] = deriv_array
np.savetxt('deriv_array_new.dat', mc2)

#  [-6.01946716e-34]
#  [-4.75242222e-34]
#  [-3.74073698e-34]
#  [-2.93506527e-34]
#  [-2.29519431e-34]
#  [-1.78851483e-34]
#  [-1.38847774e-34]
#  [-1.07368654e-34]
#  [-8.26805857e-35]
#  [-6.33893813e-35]
#  [-4.83764212e-35]
#  [-3.67398474e-35]
#  [-2.77614675e-35]
#  [-2.08669880e-35]
#  [-1.56002291e-35]
#  [-1.15989413e-35]
#  [-8.57663430e-36]
#  [-6.30763072e-36]
#  [-4.61507941e-36]
#  [-3.36085614e-36]
#  [-2.43749529e-36]
#  [-1.76187592e-36]
#  [-1.27036898e-36]
#  [-9.14342809e-37]
#  [-6.57352502e-37]
#  [-4.72117112e-37]
#  [-3.38740830e-37]
#  [-2.42800924e-37]
#  [-1.73867979e-37]
#  [-1.24429013e-37]
#  [-8.89630152e-38]
#  [-6.35902527e-38]
#  [-4.54212805e-38]
#  [-3.24458189e-38]
#  [-2.31682463e-38]
#  [-1.65540133e-38]
#  [-1.18370532e-38]
#  [-8.45959313e-39]
#  [-6.06144474e-39]
#  [-4.34048705e-39]
#  [-3.11566065e-39]
#  [-2.23690345e-39]
#  [-1.60862188e-39]
#  [-1.15842250e-39]
#  [-8.37393244e-40]
#  [-6.00767318e-40]
#  [-4.37730987e-40]
#  [-3.13721254e-40]
#  [-2.29019638e-40]
#  [-1.64766124e-40]
#  [-1.19742279e-40]
#  [-8.63827110e-41]
#  [-6.37252796e-41]
#  [-4.41120017e-41]
#  [-3.42881649e-41]
#  [-2.41542467e-41]
#  [-1.71810118e-41]
#  [-1.27712879e-41]
#  [-9.25613160e-42]
#  [-6.76139309e-42]
#  [-4.62410395e-42]
#  [-3.81168077e-42]
#  [-2.48750191e-42]
#  [-2.03633520e-42]
#  [-1.19234341e-42]
#  [-1.07367642e-42]
#  [-7.15756312e-43]
#  [-6.18304005e-43]
#  [-2.61032103e-43]
#  [-5.44528871e-43]
#  [-7.63997163e-44]
#  [-1.21481648e-43]
#  [-6.77713092e-44]
#  [-4.69459165e-44]
#  [-1.22309049e-43]
#  [-2.15061418e-44]
#  [ 1.65075303e-44]
#  [-5.79095365e-44]
#  [ 6.21295277e-45]
#  [ 1.87792486e-44]
#  [ 8.95146699e-45]
#  [-4.38869099e-44]
#  [ 1.69356100e-44]
#  [ 0.00000000e+00]]

# %% [markdown]
# ## load the result

# %%
deriv_array = np.loadtxt('deriv_array.dat')

# %%
for i in range(t_num):
    plt.plot(Omega_x, mc2[:, 1+i], label=f't = {t_arr[i]:.1e}')
    
plt.legend(loc = 'upper right')
plt.xlabel(r'$\theta$ [rad]', fontsize=14)
plt.ylabel('n<1/$\gamma$>P($\Omega$) [$\mathrm{cm}^{-3}\mathrm{sr}^{-1}$]', fontsize=14)
#plt.xlim([1e-8, 1e-3])
#plt.ylim([1e-24, 1e-16])
plt.tick_params(axis='both', which='major', labelsize=12)
plt.xscale('log')
#plt.yscale('log')
plt.grid(True)
plt.savefig('coulomb_scattering.pdf', bbox_inches='tight')
plt.show()
